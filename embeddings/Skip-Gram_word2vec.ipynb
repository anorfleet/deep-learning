# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
import math
from collections import Counter
import random
def P_w(word, word_freq, t=0.1):
    freq = word_freq[word] 
    p = 1 - (math.sqrt(t / freq))
    return p if p > 0 else 0

# %%
## Your code here

word_freq = Counter(int_words)
total = len(int_words)
for k, v in word_freq.items():
    word_freq[k] = v/total
    
train_words = []
for word in int_words:
    if np.random.random() > P_w(word, word_freq, t=0.001):
        train_words.append(word)

# %%
len(train_words)
# Out:
# 11659790

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    after = words[idx+1:(idx+R+1)]
    start = idx-R if idx - R > 0 else 0
    before = words[start:idx]
    
    return (after + before)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32,(None), name = 'inputs')
    labels = tf.placeholder(tf.int32,(None,None), name = 'labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding),-1,1), name='embedding')
    embed = tf.nn.embedding_lookup(embedding, inputs, name='embed')

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding)))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 2
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/2 Iteration: 100 Avg. Training loss: 19.3943 0.0977 sec/batch
# Epoch 1/2 Iteration: 200 Avg. Training loss: 19.0750 0.0960 sec/batch
# Epoch 1/2 Iteration: 300 Avg. Training loss: 18.8617 0.0952 sec/batch
# Epoch 1/2 Iteration: 400 Avg. Training loss: 18.4980 0.0832 sec/batch
# Epoch 1/2 Iteration: 500 Avg. Training loss: 18.3128 0.0790 sec/batch
# Epoch 1/2 Iteration: 600 Avg. Training loss: 17.9403 0.0877 sec/batch
# Epoch 1/2 Iteration: 700 Avg. Training loss: 17.6116 0.0942 sec/batch
# Epoch 1/2 Iteration: 800 Avg. Training loss: 17.2980 0.0923 sec/batch
# Epoch 1/2 Iteration: 900 Avg. Training loss: 17.1868 0.0820 sec/batch
# Epoch 1/2 Iteration: 1000 Avg. Training loss: 16.9127 0.0830 sec/batch
# Nearest to three: israeli, hurled, lacaille, stibitz, ah, friedrich, roof, featureless,
# Nearest to time: raeder, benton, margarita, disregard, cyanine, cee, directional, amplitudes,
# Nearest to to: foretold, enraged, randomization, referring, polygram, sunbury, dissipation, sovereigns,
# Nearest to the: slashed, emden, shaggy, patriots, microtonal, racquetball, empted, avtovaz,
# Nearest to nine: overcoming, overstretched, tuner, dadaists, macromedia, acoustical, fully, exclaves,
# Nearest to states: pluricentric, spiritism, endomembrane, lessen, cannibal, dissolution, eysteinn, husserl,
# Nearest to th: prismatic, orcus, sturdy, koninkrijk, vis, gumby, melanoleuca, ibo,
# Nearest to an: shania, moselle, airliner, agathon, jerome, purify, digest, knitting,
# Nearest to bill: starvation, josiah, superiores, unintelligent, uk, versification, oblique, turbocharger,
# Nearest to stage: correspondence, fittings, packard, fcc, polydor, johanna, kipchak, hond,
# Nearest to pope: fir, genscher, neko, widgets, restraining, found, mines, unleashed,
# Nearest to channel: criminalized, reviewing, entwined, nanotechnology, bounding, shorted, unharmed, hub,
# Nearest to shows: clogged, styria, vedas, beachcomber, aphorism, aegeas, walkie, smithson,
# Nearest to dr: ttt, tabu, orphans, spent, helpdesk, virtualization, banknote, exxon,
# Nearest to bbc: eidolon, map, satisfiable, umbria, damasio, stay, arguable, youthful,
# Nearest to existence: tage, acuff, melanie, trajectory, civilized, kissed, gren, govt,
# Epoch 1/2 Iteration: 1100 Avg. Training loss: 16.6913 0.0853 sec/batch
# Epoch 1/2 Iteration: 1200 Avg. Training loss: 16.4381 0.0847 sec/batch
# Epoch 1/2 Iteration: 1300 Avg. Training loss: 16.2046 0.0860 sec/batch
# Epoch 1/2 Iteration: 1400 Avg. Training loss: 16.1556 0.0889 sec/batch
# Epoch 1/2 Iteration: 1500 Avg. Training loss: 15.7932 0.1108 sec/batch
# Epoch 1/2 Iteration: 1600 Avg. Training loss: 15.5431 0.1136 sec/batch
# Epoch 1/2 Iteration: 1700 Avg. Training loss: 15.3077 0.1130 sec/batch
# Epoch 1/2 Iteration: 1800 Avg. Training loss: 15.2100 0.1158 sec/batch
# Epoch 1/2 Iteration: 1900 Avg. Training loss: 14.8195 0.1168 sec/batch
# Epoch 1/2 Iteration: 2000 Avg. Training loss: 14.6692 0.1177 sec/batch
# Nearest to three: friedrich, hurled, ah, israeli, featureless, dead, bioavailability, kap,
# Nearest to time: raeder, benton, margarita, forest, amplitudes, disregard, cee, jacobsen,
# Nearest to to: referring, enraged, foretold, randomization, saint, dissipation, polygram, queries,
# Nearest to the: slashed, can, emden, shaggy, patriots, mason, avtovaz, wan,
# Nearest to nine: overcoming, fully, exclaves, tuner, macromedia, acoustical, overstretched, also,
# Nearest to states: spiritism, pluricentric, endomembrane, lessen, eventually, dissolution, husserl, vicomte,
# Nearest to th: prismatic, four, orcus, koninkrijk, to, vis, qpl, aerobatics,
# Nearest to an: moselle, agathon, purify, vonnegut, digest, salinas, muscle, pfizer,
# Nearest to bill: starvation, josiah, superiores, unintelligent, oblique, turbocharger, assumes, corrupted,
# Nearest to stage: correspondence, fittings, packard, fcc, polydor, johanna, kipchak, hond,
# Nearest to pope: fir, genscher, neko, found, mines, widgets, restraining, cyclist,
# Nearest to channel: criminalized, reviewing, entwined, nanotechnology, bounding, shorted, unharmed, hub,
# Nearest to shows: clogged, beachcomber, styria, aphorism, aegeas, vedas, walkie, romanoff,
# Nearest to dr: ttt, tabu, spent, orphans, helpdesk, banknote, exxon, virtualization,
# Nearest to bbc: eidolon, map, satisfiable, stay, damasio, youthful, arguable, umbria,
# Nearest to existence: tage, acuff, trajectory, melanie, civilized, govt, kissed, gren,
# Epoch 1/2 Iteration: 2100 Avg. Training loss: 14.4000 0.1195 sec/batch
# Epoch 1/2 Iteration: 2200 Avg. Training loss: 14.1261 0.1202 sec/batch
# Epoch 1/2 Iteration: 2300 Avg. Training loss: 13.9187 0.1211 sec/batch
# Epoch 1/2 Iteration: 2400 Avg. Training loss: 13.7761 0.1213 sec/batch
# Epoch 1/2 Iteration: 2500 Avg. Training loss: 13.6368 0.1219 sec/batch
# Epoch 1/2 Iteration: 2600 Avg. Training loss: 13.3913 0.1222 sec/batch
# Epoch 1/2 Iteration: 2700 Avg. Training loss: 13.2205 0.1233 sec/batch
# Epoch 1/2 Iteration: 2800 Avg. Training loss: 13.0483 0.1246 sec/batch
# Epoch 1/2 Iteration: 2900 Avg. Training loss: 12.7852 0.1251 sec/batch
# Epoch 1/2 Iteration: 3000 Avg. Training loss: 12.7155 0.1280 sec/batch
# Nearest to three: israeli, ah, friedrich, year, dead, great, hurled, most,
# Nearest to time: raeder, benton, jacobsen, forest, this, cee, mixer, amplitudes,
# Nearest to to: referring, can, saint, with, flank, th, a, up,
# Nearest to the: can, most, as, on, which, least, slashed, not,
# Nearest to nine: fully, also, overcoming, macromedia, acoustical, tuner, exclaves, contribute,
# Nearest to states: spiritism, eventually, endomembrane, pluricentric, husserl, lessen, thermonuclear, problems,
# Nearest to th: four, prismatic, to, orcus, koninkrijk, denard, walks, qpl,
# Nearest to an: us, agathon, fourth, drought, purify, all, moselle, official,
# Nearest to bill: starvation, josiah, superiores, unintelligent, turbocharger, assumes, oblique, versification,
# Nearest to stage: correspondence, fittings, packard, fcc, polydor, johanna, hond, infants,
# Nearest to pope: fir, found, genscher, mines, neko, transmutation, observe, cyclist,
# Nearest to channel: reviewing, nanotechnology, criminalized, entwined, bounding, shorted, interchangeability, unharmed,
# Nearest to shows: clogged, aphorism, styria, beachcomber, vedas, aegeas, romanoff, walkie,
# Nearest to dr: ttt, spent, tabu, orphans, exxon, banknote, helpdesk, virtualization,
# Nearest to bbc: eidolon, map, satisfiable, stay, youthful, damasio, arguable, gentileschi,
# Nearest to existence: trajectory, tage, acuff, melanie, civilized, watashi, anime, remedial,
# Epoch 1/2 Iteration: 3100 Avg. Training loss: 12.4780 0.1288 sec/batch
# Epoch 1/2 Iteration: 3200 Avg. Training loss: 12.3155 0.1274 sec/batch
# Epoch 1/2 Iteration: 3300 Avg. Training loss: 12.0517 0.1290 sec/batch
# Epoch 1/2 Iteration: 3400 Avg. Training loss: 12.0394 0.1281 sec/batch
# Epoch 1/2 Iteration: 3500 Avg. Training loss: 11.9688 0.1278 sec/batch
# Epoch 1/2 Iteration: 3600 Avg. Training loss: 11.8101 0.1269 sec/batch
# Epoch 1/2 Iteration: 3700 Avg. Training loss: 11.6363 0.1271 sec/batch
# Epoch 1/2 Iteration: 3800 Avg. Training loss: 11.4671 0.1265 sec/batch
# Epoch 1/2 Iteration: 3900 Avg. Training loss: 11.3091 0.1264 sec/batch
# Epoch 1/2 Iteration: 4000 Avg. Training loss: 10.9811 0.1285 sec/batch
# Nearest to three: that, year, in, israeli, the, most, passes, great,
# Nearest to time: the, this, also, of, a, which, raeder, jacobsen,
# Nearest to to: a, of, with, the, this, and, it, as,
# Nearest to the: as, a, of, and, which, on, in, also,
# Nearest to nine: also, fully, but, contribute, acoustical, international, former, macromedia,
# Nearest to states: other, eventually, spiritism, non, see, endomembrane, in, pluricentric,
# Nearest to th: four, to, from, prismatic, with, this, proceeds, individual,
# Nearest to an: of, a, as, the, and, all, have, us,
# Nearest to bill: starvation, josiah, superiores, unintelligent, assumes, turbocharger, reestablished, oblique,
# Nearest to stage: correspondence, packard, fittings, fcc, polydor, anhui, hond, loser,
# Nearest to pope: fir, found, mines, transmutation, help, neko, cyclist, punts,
# Nearest to channel: reviewing, nanotechnology, entwined, criminalized, shorted, solve, earliest, interchangeability,
# Nearest to shows: clogged, aphorism, beachcomber, walkie, romanoff, styria, theresa, fips,
# Nearest to dr: ttt, spent, orphans, exxon, tabu, banknote, especially, energy,
# Nearest to bbc: eidolon, map, satisfiable, stay, reading, youthful, gentileschi, damasio,
# Nearest to existence: trajectory, melanie, tage, acuff, civilized, watashi, retitled, situation,
# Epoch 1/2 Iteration: 4100 Avg. Training loss: 10.9677 0.1287 sec/batch
# Epoch 1/2 Iteration: 4200 Avg. Training loss: 10.9612 0.1309 sec/batch
# Epoch 1/2 Iteration: 4300 Avg. Training loss: 10.7121 0.1277 sec/batch
# Epoch 1/2 Iteration: 4400 Avg. Training loss: 10.7302 0.1281 sec/batch
# Epoch 1/2 Iteration: 4500 Avg. Training loss: 10.4821 0.1305 sec/batch
# Epoch 1/2 Iteration: 4600 Avg. Training loss: 10.4284 0.1316 sec/batch
# Epoch 1/2 Iteration: 4700 Avg. Training loss: 10.4026 0.1298 sec/batch
# Epoch 1/2 Iteration: 4800 Avg. Training loss: 10.2584 0.1306 sec/batch
# Epoch 1/2 Iteration: 4900 Avg. Training loss: 10.2169 0.1278 sec/batch
# Epoch 1/2 Iteration: 5000 Avg. Training loss: 9.8417 0.1309 sec/batch
# Nearest to three: in, the, with, from, a, other, and, that,
# Nearest to time: the, this, also, of, a, to, is, and,
# Nearest to to: the, a, of, and, with, as, in, is,
# Nearest to the: of, and, a, in, to, as, from, which,
# Nearest to nine: also, from, is, the, in, of, by, an,
# Nearest to states: other, in, and, on, is, a, see, the,
# Nearest to th: four, to, from, s, with, this, an, on,
# Nearest to an: a, of, the, and, to, as, in, with,
# Nearest to bill: starvation, josiah, reestablished, uk, turbocharger, superiores, assumes, point,
# Nearest to stage: correspondence, packard, fittings, anhui, about, grants, ministerio, polydor,
# Nearest to pope: fir, found, help, mines, boiling, neko, cyclist, observe,
# Nearest to channel: reviewing, nanotechnology, solve, entwined, earliest, shorted, criminalized, investigation,
# Nearest to shows: clogged, has, aphorism, romanoff, common, walkie, fips, beachcomber,
# Nearest to dr: spent, ttt, exxon, orphans, especially, energy, tabu, important,
# Nearest to bbc: reading, eidolon, stay, youthful, map, satisfiable, brodie, class,
# Nearest to existence: trajectory, melanie, acuff, civilized, retitled, watashi, text, rocky,
# Epoch 1/2 Iteration: 5100 Avg. Training loss: 9.7646 0.1301 sec/batch
# Epoch 1/2 Iteration: 5200 Avg. Training loss: 9.7026 0.1284 sec/batch
# Epoch 1/2 Iteration: 5300 Avg. Training loss: 9.6720 0.1322 sec/batch
# Epoch 1/2 Iteration: 5400 Avg. Training loss: 9.5926 0.1367 sec/batch
# Epoch 1/2 Iteration: 5500 Avg. Training loss: 9.5438 0.1373 sec/batch
# Epoch 1/2 Iteration: 5600 Avg. Training loss: 9.4402 0.1370 sec/batch
# Epoch 1/2 Iteration: 5700 Avg. Training loss: 9.2846 0.1353 sec/batch
# Epoch 1/2 Iteration: 5800 Avg. Training loss: 9.3445 0.1335 sec/batch
# Epoch 1/2 Iteration: 5900 Avg. Training loss: 9.1846 0.1352 sec/batch
# Epoch 1/2 Iteration: 6000 Avg. Training loss: 9.1516 0.1348 sec/batch
# Nearest to three: two, one, zero, in, and, s, by, from,
# Nearest to time: this, the, of, a, in, only, and, to,
# Nearest to to: a, the, and, which, with, of, in, by,
# Nearest to the: of, and, in, a, to, with, by, from,
# Nearest to nine: one, two, zero, in, s, of, from, and,
# Nearest to states: other, the, and, in, of, on, also, from,
# Nearest to th: four, on, s, from, was, the, and, early,
# Nearest to an: a, the, to, and, of, in, with, this,
# Nearest to bill: starvation, josiah, three, uk, reestablished, two, rockstar, assumes,
# Nearest to stage: correspondence, packard, anhui, ministerio, about, grants, somehow, fittings,
# Nearest to pope: fir, mines, help, boiling, found, observe, distribution, cyclist,
# Nearest to channel: reviewing, solve, nanotechnology, entwined, earliest, investigation, shorted, jur,
# Nearest to shows: has, modern, common, clogged, when, between, whenever, there,
# Nearest to dr: spent, ttt, especially, exxon, orphans, energy, importance, important,
# Nearest to bbc: reading, stay, eidolon, map, youthful, elaborate, class, unsuccessful,
# Nearest to existence: trajectory, part, text, watashi, civilized, friction, avoid, ordinary,
# Epoch 1/2 Iteration: 6100 Avg. Training loss: 9.0198 0.1352 sec/batch
# Epoch 1/2 Iteration: 6200 Avg. Training loss: 9.5091 0.1319 sec/batch
# Epoch 1/2 Iteration: 6300 Avg. Training loss: 8.8819 0.1294 sec/batch
# Epoch 1/2 Iteration: 6400 Avg. Training loss: 8.8677 0.1299 sec/batch
# Epoch 1/2 Iteration: 6500 Avg. Training loss: 8.6347 0.1368 sec/batch
# Epoch 1/2 Iteration: 6600 Avg. Training loss: 8.6455 0.1303 sec/batch
# Epoch 1/2 Iteration: 6700 Avg. Training loss: 8.4875 0.1305 sec/batch
# Epoch 1/2 Iteration: 6800 Avg. Training loss: 8.5294 0.1303 sec/batch
# Epoch 1/2 Iteration: 6900 Avg. Training loss: 8.5661 0.1309 sec/batch
# Epoch 1/2 Iteration: 7000 Avg. Training loss: 8.5228 0.1323 sec/batch
# Nearest to three: two, one, zero, four, five, eight, s, seven,
# Nearest to time: the, this, to, with, at, however, of, and,
# Nearest to to: which, the, and, this, a, for, it, with,
# Nearest to the: in, of, and, with, a, from, to, by,
# Nearest to nine: one, two, three, four, zero, five, eight, s,
# Nearest to states: its, by, other, s, the, between, on, in,
# Nearest to th: early, during, four, was, on, s, one, by,
# Nearest to an: a, the, and, with, in, to, which, this,
# Nearest to bill: three, josiah, starvation, one, uk, seven, two, reestablished,
# Nearest to stage: correspondence, packard, somehow, ministerio, grants, anhui, started, fittings,
# Nearest to pope: help, mines, fir, could, found, observe, distribution, boiling,
# Nearest to channel: reviewing, solve, nanotechnology, entwined, investigation, earliest, older, jur,
# Nearest to shows: modern, common, there, for, most, has, all, and,
# Nearest to dr: spent, ttt, especially, exxon, importance, energy, important, influences,
# Nearest to bbc: reading, stay, eidolon, map, class, elaborate, unsuccessful, youthful,
# Nearest to existence: trajectory, part, being, systems, text, quite, book, jagiello,
# Epoch 1/2 Iteration: 7100 Avg. Training loss: 8.4487 0.1333 sec/batch
# Epoch 1/2 Iteration: 7200 Avg. Training loss: 8.3934 0.1318 sec/batch
# Epoch 1/2 Iteration: 7300 Avg. Training loss: 8.0841 0.1315 sec/batch
# Epoch 1/2 Iteration: 7400 Avg. Training loss: 8.1912 0.1303 sec/batch
# Epoch 1/2 Iteration: 7500 Avg. Training loss: 8.1350 0.1299 sec/batch
# Epoch 1/2 Iteration: 7600 Avg. Training loss: 8.0174 0.1312 sec/batch
# Epoch 1/2 Iteration: 7700 Avg. Training loss: 8.1400 0.1321 sec/batch
# Epoch 1/2 Iteration: 7800 Avg. Training loss: 7.9634 0.1397 sec/batch
# Epoch 1/2 Iteration: 7900 Avg. Training loss: 7.9495 0.1498 sec/batch
# Epoch 1/2 Iteration: 8000 Avg. Training loss: 8.0902 0.1348 sec/batch
# Nearest to three: four, two, one, five, zero, eight, six, nine,
# Nearest to time: the, in, for, from, of, to, with, this,
# Nearest to to: the, with, for, this, a, and, which, only,
# Nearest to the: of, in, and, by, from, on, to, with,
# Nearest to nine: one, four, eight, five, three, two, zero, six,
# Nearest to states: were, the, in, of, from, its, between, and,
# Nearest to th: early, during, were, four, one, was, until, before,
# Nearest to an: a, and, the, by, in, with, of, to,
# Nearest to bill: number, josiah, five, three, two, seven, starvation, one,
# Nearest to stage: correspondence, packard, somehow, name, war, allow, ministerio, started,
# Nearest to pope: help, mines, found, boiling, distribution, media, attention, observe,
# Nearest to channel: reviewing, solve, investigation, older, nanotechnology, entwined, earliest, practically,
# Nearest to shows: modern, common, long, made, several, when, all, an,
# Nearest to dr: spent, ttt, importance, exxon, important, energy, moved, november,
# Nearest to bbc: reading, stay, transferred, unsuccessful, map, class, elaborate, eidolon,
# Nearest to existence: trajectory, systems, quite, based, text, being, freeman, book,
# Epoch 1/2 Iteration: 8100 Avg. Training loss: 7.7883 0.1370 sec/batch
# Epoch 1/2 Iteration: 8200 Avg. Training loss: 7.6220 0.1357 sec/batch
# Epoch 1/2 Iteration: 8300 Avg. Training loss: 7.6539 0.1346 sec/batch
# Epoch 1/2 Iteration: 8400 Avg. Training loss: 7.5856 0.1313 sec/batch
# Epoch 1/2 Iteration: 8500 Avg. Training loss: 7.5995 0.1334 sec/batch
# Epoch 1/2 Iteration: 8600 Avg. Training loss: 7.5908 0.1340 sec/batch
# Epoch 1/2 Iteration: 8700 Avg. Training loss: 7.4962 0.1177 sec/batch
# Epoch 1/2 Iteration: 8800 Avg. Training loss: 7.4910 0.1045 sec/batch
# Epoch 1/2 Iteration: 8900 Avg. Training loss: 7.5143 0.1293 sec/batch
# Epoch 1/2 Iteration: 9000 Avg. Training loss: 7.2678 0.1024 sec/batch
# Nearest to three: four, two, five, six, one, eight, zero, seven,
# Nearest to time: the, was, to, with, a, made, that, later,
# Nearest to to: which, a, the, only, however, while, with, but,
# Nearest to the: of, from, by, in, a, and, with, to,
# Nearest to nine: one, eight, seven, four, six, three, five, two,
# Nearest to states: united, the, in, of, first, from, and, world,
# Nearest to th: early, until, on, first, in, of, year, the,
# Nearest to an: a, the, which, by, for, to, with, only,
# Nearest to bill: u, two, james, new, zero, and, first, four,
# Nearest to stage: correspondence, somehow, name, war, packard, played, started, third,
# Nearest to pope: help, mines, boiling, distribution, later, fir, punished, observe,
# Nearest to channel: reviewing, older, solve, practically, investigation, nanotechnology, set, entwined,
# Nearest to shows: modern, common, at, there, for, known, several, have,
# Nearest to dr: spent, moved, ttt, kingdom, november, importance, energy, expressed,
# Nearest to bbc: reading, recent, stay, external, map, oppose, transferred, unsuccessful,
# Nearest to existence: systems, certain, important, according, will, book, trajectory, based,
# Epoch 1/2 Iteration: 9100 Avg. Training loss: 7.3535 0.1170 sec/batch
# Epoch 1/2 Iteration: 9200 Avg. Training loss: 7.3224 0.1165 sec/batch
# Epoch 1/2 Iteration: 9300 Avg. Training loss: 7.2995 0.1164 sec/batch
# Epoch 1/2 Iteration: 9400 Avg. Training loss: 7.2645 0.1024 sec/batch
# Epoch 1/2 Iteration: 9500 Avg. Training loss: 7.4897 0.1021 sec/batch
# Epoch 1/2 Iteration: 9600 Avg. Training loss: 7.5461 0.1025 sec/batch
# Epoch 1/2 Iteration: 9700 Avg. Training loss: 7.3190 0.1030 sec/batch
# Epoch 1/2 Iteration: 9800 Avg. Training loss: 7.0728 0.1029 sec/batch
# Epoch 1/2 Iteration: 9900 Avg. Training loss: 6.9026 0.1030 sec/batch
# Epoch 1/2 Iteration: 10000 Avg. Training loss: 7.1235 0.1032 sec/batch
# Nearest to three: four, five, six, two, one, seven, eight, nine,
# Nearest to time: the, to, with, however, was, but, a, were,
# Nearest to to: a, the, which, and, for, of, with, an,
# Nearest to the: of, in, and, by, from, with, to, a,
# Nearest to nine: one, eight, seven, six, four, three, five, two,
# Nearest to states: united, in, the, of, and, by, first, from,
# Nearest to th: late, early, century, until, first, one, six, in,
# Nearest to an: a, and, the, to, of, with, which, by,
# Nearest to bill: james, u, first, josiah, almost, elected, five, second,
# Nearest to stage: correspondence, name, third, played, war, later, he, made,
# Nearest to pope: help, mines, boiling, england, lost, he, took, along,
# Nearest to channel: reviewing, solve, older, investigation, practically, nanotechnology, set, october,
# Nearest to shows: for, at, called, several, number, and, there, both,
# Nearest to dr: moved, spent, november, importance, eventually, started, southern, ttt,
# Nearest to bbc: popular, reading, claim, oppose, map, recent, france, ten,
# Nearest to existence: systems, book, being, not, recent, often, itself, quite,
# Epoch 1/2 Iteration: 10100 Avg. Training loss: 7.2483 0.1042 sec/batch
# Epoch 1/2 Iteration: 10200 Avg. Training loss: 7.2809 0.1026 sec/batch
# Epoch 1/2 Iteration: 10300 Avg. Training loss: 7.2300 0.1026 sec/batch
# Epoch 1/2 Iteration: 10400 Avg. Training loss: 7.1281 0.1022 sec/batch
# Epoch 1/2 Iteration: 10500 Avg. Training loss: 7.0451 0.1038 sec/batch
# Epoch 1/2 Iteration: 10600 Avg. Training loss: 6.7788 0.1024 sec/batch
# Epoch 1/2 Iteration: 10700 Avg. Training loss: 6.6971 0.1029 sec/batch
# Epoch 1/2 Iteration: 10800 Avg. Training loss: 6.8716 0.1032 sec/batch
# Epoch 1/2 Iteration: 10900 Avg. Training loss: 6.8414 0.1024 sec/batch
# Epoch 1/2 Iteration: 11000 Avg. Training loss: 6.7518 0.1026 sec/batch
# Nearest to three: two, five, four, one, six, seven, zero, nine,
# Nearest to time: the, with, of, were, a, was, in, on,
# Nearest to to: but, which, with, this, for, a, that, the,
# Nearest to the: of, in, with, and, by, its, from, on,
# Nearest to nine: one, eight, seven, six, four, five, three, two,
# Nearest to states: united, established, national, major, in, former, the, state,
# Nearest to th: late, century, early, year, until, established, began, first,
# Nearest to an: a, by, of, the, and, for, with, in,
# Nearest to bill: james, elected, february, king, established, author, u, president,
# Nearest to stage: later, included, played, name, made, he, had, correspondence,
# Nearest to pope: he, help, him, england, lost, after, introduced, was,
# Nearest to channel: practically, solve, older, reviewing, nanotechnology, investigation, october, equipment,
# Nearest to shows: for, every, several, number, good, known, the, there,
# Nearest to dr: november, moved, president, started, spent, importance, later, southern,
# Nearest to bbc: claim, external, recent, links, france, day, oppose, on,
# Nearest to existence: systems, book, being, what, which, according, itself, recent,
# Epoch 1/2 Iteration: 11100 Avg. Training loss: 6.8543 0.1036 sec/batch
# Epoch 1/2 Iteration: 11200 Avg. Training loss: 6.8073 0.1022 sec/batch
# Epoch 1/2 Iteration: 11300 Avg. Training loss: 6.7588 0.1022 sec/batch
# Epoch 1/2 Iteration: 11400 Avg. Training loss: 6.7273 0.1013 sec/batch
# Epoch 1/2 Iteration: 11500 Avg. Training loss: 6.8080 0.1016 sec/batch
# Epoch 1/2 Iteration: 11600 Avg. Training loss: 6.7662 0.1011 sec/batch
# Epoch 2/2 Iteration: 11700 Avg. Training loss: 6.7427 0.0434 sec/batch
# Epoch 2/2 Iteration: 11800 Avg. Training loss: 6.6723 0.1029 sec/batch
# Epoch 2/2 Iteration: 11900 Avg. Training loss: 6.5011 0.1022 sec/batch
# Epoch 2/2 Iteration: 12000 Avg. Training loss: 6.6439 0.1041 sec/batch
# Nearest to three: four, two, five, one, six, zero, seven, eight,
# Nearest to time: a, the, and, with, in, to, at, were,
# Nearest to to: but, the, a, which, and, for, this, with,
# Nearest to the: in, and, of, by, a, from, to, with,
# Nearest to nine: one, eight, seven, six, four, five, three, two,
# Nearest to states: united, state, established, government, national, in, under, the,
# Nearest to th: late, early, century, until, period, beginning, began, during,
# Nearest to an: a, which, this, to, for, with, the, it,
# Nearest to bill: james, british, president, established, elected, february, u, under,
# Nearest to stage: time, earlier, played, later, were, started, whose, name,
# Nearest to pope: later, he, work, help, england, named, lost, before,
# Nearest to channel: practically, older, investigation, solve, reviewing, nanotechnology, psychological, hub,
# Nearest to shows: making, including, several, of, like, a, good, for,
# Nearest to dr: moved, times, november, spent, working, started, death, president,
# Nearest to bbc: sources, began, day, recent, france, claim, history, world,
# Nearest to existence: might, possible, being, thought, any, that, without, such,
# Epoch 2/2 Iteration: 12100 Avg. Training loss: 6.4818 0.1036 sec/batch
# Epoch 2/2 Iteration: 12200 Avg. Training loss: 6.5336 0.1022 sec/batch
# Epoch 2/2 Iteration: 12300 Avg. Training loss: 6.5493 0.1022 sec/batch
# Epoch 2/2 Iteration: 12400 Avg. Training loss: 6.4712 0.1014 sec/batch
# Epoch 2/2 Iteration: 12500 Avg. Training loss: 6.4572 0.1006 sec/batch
# Epoch 2/2 Iteration: 12600 Avg. Training loss: 6.3224 0.1009 sec/batch
# Epoch 2/2 Iteration: 12700 Avg. Training loss: 6.4096 0.1011 sec/batch
# Epoch 2/2 Iteration: 12800 Avg. Training loss: 6.4958 0.1018 sec/batch
# Epoch 2/2 Iteration: 12900 Avg. Training loss: 6.4387 0.1010 sec/batch
# Epoch 2/2 Iteration: 13000 Avg. Training loss: 6.4808 0.1016 sec/batch
# Nearest to three: four, five, six, one, two, seven, eight, nine,
# Nearest to time: with, the, while, a, which, this, however, but,
# Nearest to to: it, which, however, this, the, but, with, that,
# Nearest to the: of, in, and, a, from, with, by, which,
# Nearest to nine: one, eight, seven, six, four, five, three, two,
# Nearest to states: united, kingdom, established, government, nations, state, national, in,
# Nearest to th: late, century, early, year, until, day, beginning, began,
# Nearest to an: a, the, with, this, to, of, and, for,
# Nearest to bill: james, under, new, elected, at, president, replaced, first,
# Nearest to stage: played, originally, name, later, time, series, had, whose,
# Nearest to pope: he, england, was, his, later, him, help, founded,
# Nearest to channel: older, practically, toward, investigation, solve, reviewing, set, nanotechnology,
# Nearest to shows: for, an, with, it, the, a, there, though,
# Nearest to dr: moved, s, spent, started, november, his, president, name,
# Nearest to bbc: day, external, history, approximately, works, links, information, official,
# Nearest to existence: thought, that, idea, might, reason, it, process, be,
# Epoch 2/2 Iteration: 13100 Avg. Training loss: 6.3296 0.1039 sec/batch
# Epoch 2/2 Iteration: 13200 Avg. Training loss: 6.3050 0.1021 sec/batch
# Epoch 2/2 Iteration: 13300 Avg. Training loss: 6.2923 0.1017 sec/batch
# Epoch 2/2 Iteration: 13400 Avg. Training loss: 6.1104 0.1022 sec/batch
# Epoch 2/2 Iteration: 13500 Avg. Training loss: 6.2469 0.1023 sec/batch
# Epoch 2/2 Iteration: 13600 Avg. Training loss: 6.2509 0.1024 sec/batch
# Epoch 2/2 Iteration: 13700 Avg. Training loss: 6.2276 0.1035 sec/batch
# Epoch 2/2 Iteration: 13800 Avg. Training loss: 6.1878 0.1036 sec/batch
# Epoch 2/2 Iteration: 13900 Avg. Training loss: 6.2430 0.1039 sec/batch
# Epoch 2/2 Iteration: 14000 Avg. Training loss: 6.2809 0.1034 sec/batch
# Nearest to three: four, six, two, five, one, eight, seven, zero,
# Nearest to time: in, the, which, with, a, and, before, by,
# Nearest to to: a, this, and, but, which, the, with, it,
# Nearest to the: of, in, and, from, with, by, on, which,
# Nearest to nine: one, eight, seven, six, four, five, three, two,
# Nearest to states: kingdom, united, nations, established, state, countries, country, government,
# Nearest to th: late, century, early, mid, until, during, became, beginning,
# Nearest to an: a, and, with, the, which, of, to, in,
# Nearest to bill: s, was, first, by, after, february, title, who,
# Nearest to stage: name, originally, later, original, on, and, had, time,
# Nearest to pope: england, john, great, lost, death, founded, later, st,
# Nearest to channel: investigation, toward, older, look, current, practically, equipment, earliest,
# Nearest to shows: an, in, a, created, on, the, most, and,
# Nearest to dr: november, s, went, president, moved, took, home, spent,
# Nearest to bbc: television, created, popular, record, includes, began, september, day,
# Nearest to existence: might, reason, quite, such, idea, some, be, that,
# Epoch 2/2 Iteration: 14100 Avg. Training loss: 6.1747 0.1045 sec/batch
# Epoch 2/2 Iteration: 14200 Avg. Training loss: 6.1045 0.1032 sec/batch
# Epoch 2/2 Iteration: 14300 Avg. Training loss: 6.0046 0.1048 sec/batch
# Epoch 2/2 Iteration: 14400 Avg. Training loss: 5.9603 0.1032 sec/batch
# Epoch 2/2 Iteration: 14500 Avg. Training loss: 5.9082 0.1035 sec/batch
# Epoch 2/2 Iteration: 14600 Avg. Training loss: 6.0041 0.1039 sec/batch
# Epoch 2/2 Iteration: 14700 Avg. Training loss: 6.0382 0.1056 sec/batch
# Epoch 2/2 Iteration: 14800 Avg. Training loss: 5.9267 0.1053 sec/batch
# Epoch 2/2 Iteration: 14900 Avg. Training loss: 6.0815 0.1042 sec/batch
# Epoch 2/2 Iteration: 15000 Avg. Training loss: 5.9436 0.1045 sec/batch
# Nearest to three: two, four, five, six, zero, one, seven, eight,
# Nearest to time: this, a, only, the, while, to, an, with,
# Nearest to to: which, this, a, but, with, the, it, while,
# Nearest to the: in, and, of, from, with, to, by, which,
# Nearest to nine: eight, seven, one, six, five, four, three, two,
# Nearest to states: kingdom, united, nations, countries, u, government, established, state,
# Nearest to th: late, century, early, until, during, mid, became, centuries,
# Nearest to an: a, which, for, and, to, with, this, the,
# Nearest to bill: james, february, first, s, later, john, william, new,
# Nearest to stage: originally, from, time, in, later, were, probably, had,
# Nearest to pope: england, lived, brought, king, himself, john, he, returned,
# Nearest to channel: equipment, toward, older, look, investigation, developed, mainly, post,
# Nearest to shows: a, an, for, another, by, and, this, which,
# Nearest to dr: moved, s, founded, one, james, was, career, became,
# Nearest to bbc: department, television, world, links, created, record, today, site,
# Nearest to existence: being, thought, that, cannot, generally, reason, be, sense,
# Epoch 2/2 Iteration: 15100 Avg. Training loss: 6.0727 0.1046 sec/batch
# Epoch 2/2 Iteration: 15200 Avg. Training loss: 6.0886 0.1025 sec/batch
# Epoch 2/2 Iteration: 15300 Avg. Training loss: 6.0574 0.1024 sec/batch
# Epoch 2/2 Iteration: 15400 Avg. Training loss: 6.0301 0.1030 sec/batch
# Epoch 2/2 Iteration: 15500 Avg. Training loss: 6.0156 0.1020 sec/batch
# Epoch 2/2 Iteration: 15600 Avg. Training loss: 5.8969 0.1020 sec/batch
# Epoch 2/2 Iteration: 15700 Avg. Training loss: 5.7864 0.1050 sec/batch
# Epoch 2/2 Iteration: 15800 Avg. Training loss: 5.9747 0.1021 sec/batch
# Epoch 2/2 Iteration: 15900 Avg. Training loss: 5.9623 0.1023 sec/batch
# Epoch 2/2 Iteration: 16000 Avg. Training loss: 5.8596 0.1071 sec/batch
# Nearest to three: two, five, one, seven, six, four, zero, eight,
# Nearest to time: the, with, it, a, to, for, when, while,
# Nearest to to: it, with, and, a, which, only, but, while,
# Nearest to the: of, in, and, by, from, with, on, a,
# Nearest to nine: seven, one, eight, six, three, five, four, two,
# Nearest to states: united, kingdom, nations, countries, government, state, national, established,
# Nearest to th: century, late, early, mid, one, st, nine, s,
# Nearest to an: a, for, and, with, from, of, the, this,
# Nearest to bill: was, first, john, named, new, james, february, author,
# Nearest to stage: a, an, from, which, and, called, character, when,
# Nearest to pope: england, king, he, lived, sent, was, joined, brought,
# Nearest to channel: equipment, investigation, construction, operation, toward, given, second, international,
# Nearest to shows: for, a, an, and, another, the, also, from,
# Nearest to dr: john, robert, november, nine, one, born, seven, william,
# Nearest to bbc: records, published, department, international, television, began, news, work,
# Nearest to existence: be, that, however, not, being, thought, without, generally,
# Epoch 2/2 Iteration: 16100 Avg. Training loss: 5.8622 0.1065 sec/batch
# Epoch 2/2 Iteration: 16200 Avg. Training loss: 5.9167 0.1023 sec/batch
# Epoch 2/2 Iteration: 16300 Avg. Training loss: 5.9328 0.1019 sec/batch
# Epoch 2/2 Iteration: 16400 Avg. Training loss: 5.9004 0.1018 sec/batch
# Epoch 2/2 Iteration: 16500 Avg. Training loss: 5.8785 0.1013 sec/batch
# Epoch 2/2 Iteration: 16600 Avg. Training loss: 5.8897 0.1018 sec/batch
# Epoch 2/2 Iteration: 16700 Avg. Training loss: 5.6349 0.1015 sec/batch
# Epoch 2/2 Iteration: 16800 Avg. Training loss: 5.6555 0.1022 sec/batch
# Epoch 2/2 Iteration: 16900 Avg. Training loss: 5.7344 0.1040 sec/batch
# Epoch 2/2 Iteration: 17000 Avg. Training loss: 5.7881 0.1031 sec/batch
# Nearest to three: four, five, one, six, two, seven, eight, nine,
# Nearest to time: it, the, which, when, this, while, a, with,
# Nearest to to: this, it, which, but, that, however, for, with,
# Nearest to the: of, in, and, by, with, on, to, from,
# Nearest to nine: eight, one, seven, six, four, five, three, two,
# Nearest to states: nations, united, kingdom, countries, national, member, government, europe,
# Nearest to th: century, late, mid, early, centuries, st, during, until,
# Nearest to an: a, is, which, this, for, or, to, another,
# Nearest to bill: james, s, author, first, began, february, john, was,
# Nearest to stage: later, original, time, produced, character, with, several, was,
# Nearest to pope: iii, saw, met, brought, king, was, sent, england,
# Nearest to channel: equipment, construction, second, international, marked, commercial, operation, station,
# Nearest to shows: for, a, time, with, made, another, several, the,
# Nearest to dr: s, robert, famous, peter, john, paul, first, home,
# Nearest to bbc: began, popular, records, external, day, history, television, including,
# Nearest to existence: that, not, sense, way, view, what, true, be,
# Epoch 2/2 Iteration: 17100 Avg. Training loss: 5.7731 0.1034 sec/batch
# Epoch 2/2 Iteration: 17200 Avg. Training loss: 5.7068 0.1043 sec/batch
# Epoch 2/2 Iteration: 17300 Avg. Training loss: 5.8278 0.1041 sec/batch
# Epoch 2/2 Iteration: 17400 Avg. Training loss: 5.7062 0.1022 sec/batch
# Epoch 2/2 Iteration: 17500 Avg. Training loss: 5.6445 0.1026 sec/batch
# Epoch 2/2 Iteration: 17600 Avg. Training loss: 5.6805 0.1020 sec/batch
# Epoch 2/2 Iteration: 17700 Avg. Training loss: 5.6751 0.1018 sec/batch
# Epoch 2/2 Iteration: 17800 Avg. Training loss: 5.7040 0.1022 sec/batch
# Epoch 2/2 Iteration: 17900 Avg. Training loss: 5.9367 0.1019 sec/batch
# Epoch 2/2 Iteration: 18000 Avg. Training loss: 5.6373 0.1008 sec/batch
# Nearest to three: four, five, two, six, one, seven, zero, eight,
# Nearest to time: a, an, the, this, with, at, to, which,
# Nearest to to: a, which, this, it, but, only, with, all,
# Nearest to the: in, of, and, from, by, with, on, a,
# Nearest to nine: one, seven, eight, six, five, three, four, american,
# Nearest to states: nations, united, kingdom, government, countries, national, state, administration,
# Nearest to th: late, century, mid, early, until, st, beginning, last,
# Nearest to an: a, for, with, this, is, to, the, and,
# Nearest to bill: s, first, john, third, james, young, by, was,
# Nearest to stage: and, with, a, as, original, the, of, by,
# Nearest to pope: iii, king, england, met, returned, wife, declared, saw,
# Nearest to channel: equipment, current, detailed, network, operations, investigation, second, based,
# Nearest to shows: a, on, which, with, for, and, time, by,
# Nearest to dr: john, robert, michael, s, thomas, famous, richard, peter,
# Nearest to bbc: external, day, on, news, times, popular, television, december,
# Nearest to existence: sense, view, that, idea, not, yet, true, individual,
# Epoch 2/2 Iteration: 18100 Avg. Training loss: 5.6988 0.1019 sec/batch
# Epoch 2/2 Iteration: 18200 Avg. Training loss: 5.4874 0.1012 sec/batch
# Epoch 2/2 Iteration: 18300 Avg. Training loss: 5.4464 0.1018 sec/batch
# Epoch 2/2 Iteration: 18400 Avg. Training loss: 5.6416 0.1021 sec/batch
# Epoch 2/2 Iteration: 18500 Avg. Training loss: 5.6235 0.1024 sec/batch
# Epoch 2/2 Iteration: 18600 Avg. Training loss: 5.7270 0.1031 sec/batch
# Epoch 2/2 Iteration: 18700 Avg. Training loss: 5.6497 0.1028 sec/batch
# Epoch 2/2 Iteration: 18800 Avg. Training loss: 5.7553 0.1025 sec/batch
# Epoch 2/2 Iteration: 18900 Avg. Training loss: 5.5733 0.1029 sec/batch
# Epoch 2/2 Iteration: 19000 Avg. Training loss: 5.4880 0.1022 sec/batch
# Nearest to three: four, five, two, six, one, seven, eight, zero,
# Nearest to time: but, to, which, it, when, however, while, having,
# Nearest to to: a, but, which, however, this, only, that, and,
# Nearest to the: of, and, in, by, from, with, were, to,
# Nearest to nine: one, eight, seven, six, four, three, five, two,
# Nearest to states: nations, kingdom, united, national, member, countries, canada, germany,
# Nearest to th: century, late, early, centuries, mid, beginning, until, during,
# Nearest to an: a, with, by, for, to, and, of, the,
# Nearest to bill: first, s, joined, was, home, named, became, former,
# Nearest to stage: made, whose, style, another, for, only, having, work,
# Nearest to pope: iii, england, king, sent, son, after, brought, he,
# Nearest to channel: current, network, operations, investigation, provided, detailed, station, figures,
# Nearest to shows: show, for, another, a, original, only, an, with,
# Nearest to dr: john, robert, james, william, peter, richard, one, michael,
# Nearest to bbc: news, uk, on, television, external, history, june, s,
# Nearest to existence: view, sense, not, yet, that, nature, idea, any,
# Epoch 2/2 Iteration: 19100 Avg. Training loss: 5.5977 0.1031 sec/batch
# Epoch 2/2 Iteration: 19200 Avg. Training loss: 5.5400 0.1017 sec/batch
# Epoch 2/2 Iteration: 19300 Avg. Training loss: 5.4915 0.1022 sec/batch
# Epoch 2/2 Iteration: 19400 Avg. Training loss: 5.6351 0.1029 sec/batch
# Epoch 2/2 Iteration: 19500 Avg. Training loss: 5.5435 0.1030 sec/batch
# Epoch 2/2 Iteration: 19600 Avg. Training loss: 5.6115 0.1026 sec/batch
# Epoch 2/2 Iteration: 19700 Avg. Training loss: 5.6251 0.1028 sec/batch
# Epoch 2/2 Iteration: 19800 Avg. Training loss: 5.3499 0.1025 sec/batch
# Epoch 2/2 Iteration: 19900 Avg. Training loss: 5.3880 0.1029 sec/batch
# Epoch 2/2 Iteration: 20000 Avg. Training loss: 5.5049 0.1026 sec/batch
# Nearest to three: five, four, one, two, six, seven, zero, eight,
# Nearest to time: the, to, but, while, at, in, this, when,
# Nearest to to: but, it, only, which, that, this, however, a,
# Nearest to the: in, of, and, by, from, with, its, on,
# Nearest to nine: eight, seven, six, one, four, five, three, two,
# Nearest to states: nations, united, kingdom, countries, state, government, governments, nation,
# Nearest to th: century, late, centuries, early, mid, beginning, period, until,
# Nearest to an: a, for, this, with, to, is, which, also,
# Nearest to bill: act, leaving, was, member, passed, first, by, s,
# Nearest to stage: performed, made, having, but, actually, first, time, work,
# Nearest to pope: england, iii, edward, he, james, death, king, died,
# Nearest to channel: network, via, support, set, current, additional, for, then,
# Nearest to shows: show, original, for, a, another, features, on, also,
# Nearest to dr: john, james, thomas, michael, robert, peter, richard, paul,
# Nearest to bbc: news, television, uk, media, references, site, series, online,
# Nearest to existence: that, itself, all, yet, but, being, though, this,
# Epoch 2/2 Iteration: 20100 Avg. Training loss: 5.3875 0.1059 sec/batch
# Epoch 2/2 Iteration: 20200 Avg. Training loss: 5.4510 0.1052 sec/batch
# Epoch 2/2 Iteration: 20300 Avg. Training loss: 5.3707 0.1046 sec/batch
# Epoch 2/2 Iteration: 20400 Avg. Training loss: 5.4126 0.1049 sec/batch
# Epoch 2/2 Iteration: 20500 Avg. Training loss: 5.1951 0.1041 sec/batch
# Epoch 2/2 Iteration: 20600 Avg. Training loss: 5.5204 0.1024 sec/batch
# Epoch 2/2 Iteration: 20700 Avg. Training loss: 5.3001 0.1022 sec/batch
# Epoch 2/2 Iteration: 20800 Avg. Training loss: 5.4118 0.1025 sec/batch
# Epoch 2/2 Iteration: 20900 Avg. Training loss: 5.3902 0.1022 sec/batch
# Epoch 2/2 Iteration: 21000 Avg. Training loss: 5.4079 0.1029 sec/batch
# Nearest to three: four, five, six, two, one, seven, eight, zero,
# Nearest to time: with, a, when, while, the, for, and, to,
# Nearest to to: a, which, the, only, however, but, that, and,
# Nearest to the: of, and, in, from, a, to, an, by,
# Nearest to nine: one, seven, six, eight, four, three, five, two,
# Nearest to states: united, kingdom, u, state, nations, national, established, congress,
# Nearest to th: century, late, early, nd, rd, centuries, year, period,
# Nearest to an: and, a, the, of, in, with, for, by,
# Nearest to bill: s, nine, british, former, first, one, leader, professional,
# Nearest to stage: famous, with, film, a, worked, was, s, his,
# Nearest to pope: iii, england, king, henry, edward, john, son, wife,
# Nearest to channel: network, set, via, users, operations, alternative, operation, now,
# Nearest to shows: original, produced, a, classic, feature, including, for, also,
# Nearest to dr: michael, john, william, paul, richard, thomas, one, nine,
# Nearest to bbc: external, news, links, times, june, day, references, uk,
# Nearest to existence: therefore, fact, such, some, that, nature, this, practice,
# Epoch 2/2 Iteration: 21100 Avg. Training loss: 5.5002 0.1038 sec/batch
# Epoch 2/2 Iteration: 21200 Avg. Training loss: 5.6363 0.1029 sec/batch
# Epoch 2/2 Iteration: 21300 Avg. Training loss: 5.6655 0.1026 sec/batch
# Epoch 2/2 Iteration: 21400 Avg. Training loss: 5.4338 0.1029 sec/batch
# Epoch 2/2 Iteration: 21500 Avg. Training loss: 5.2712 0.1032 sec/batch
# Epoch 2/2 Iteration: 21600 Avg. Training loss: 5.2221 0.1096 sec/batch
# Epoch 2/2 Iteration: 21700 Avg. Training loss: 5.4767 0.1043 sec/batch
# Epoch 2/2 Iteration: 21800 Avg. Training loss: 5.5430 0.1081 sec/batch
# Epoch 2/2 Iteration: 21900 Avg. Training loss: 5.4972 0.1026 sec/batch
# Epoch 2/2 Iteration: 22000 Avg. Training loss: 5.4863 0.1030 sec/batch
# Nearest to three: four, five, one, two, six, seven, eight, zero,
# Nearest to time: to, a, an, only, with, the, this, but,
# Nearest to to: but, only, which, that, a, with, this, however,
# Nearest to the: and, in, from, by, of, on, with, an,
# Nearest to nine: one, seven, eight, four, six, three, five, two,
# Nearest to states: united, nations, kingdom, governments, state, federal, government, countries,
# Nearest to th: century, late, centuries, rd, early, nd, mid, st,
# Nearest to an: a, for, and, the, which, to, by, with,
# Nearest to bill: president, announced, british, former, american, house, s, was,
# Nearest to stage: produced, appeared, play, film, movie, featured, performed, plays,
# Nearest to pope: iii, england, king, henry, son, emperor, john, wife,
# Nearest to channel: independent, via, network, program, satellite, between, station, operation,
# Nearest to shows: original, for, a, another, as, based, on, feature,
# Nearest to dr: john, david, paul, robert, peter, william, richard, thomas,
# Nearest to bbc: news, uk, times, radio, external, july, media, television,
# Nearest to existence: that, evidence, nature, idea, some, this, have, not,
# Epoch 2/2 Iteration: 22100 Avg. Training loss: 5.3692 0.1098 sec/batch
# Epoch 2/2 Iteration: 22200 Avg. Training loss: 5.3983 0.1133 sec/batch
# Epoch 2/2 Iteration: 22300 Avg. Training loss: 5.1444 0.1017 sec/batch
# Epoch 2/2 Iteration: 22400 Avg. Training loss: 5.2165 0.1025 sec/batch
# Epoch 2/2 Iteration: 22500 Avg. Training loss: 5.3745 0.1086 sec/batch
# Epoch 2/2 Iteration: 22600 Avg. Training loss: 5.2097 0.1029 sec/batch
# Epoch 2/2 Iteration: 22700 Avg. Training loss: 5.2604 0.1057 sec/batch
# Epoch 2/2 Iteration: 22800 Avg. Training loss: 5.4021 0.1035 sec/batch
# Epoch 2/2 Iteration: 22900 Avg. Training loss: 5.3464 0.1020 sec/batch
# Epoch 2/2 Iteration: 23000 Avg. Training loss: 5.2805 0.1018 sec/batch
# Nearest to three: four, five, one, two, six, seven, eight, nine,
# Nearest to time: was, the, in, on, to, made, with, when,
# Nearest to to: but, however, that, with, a, their, which, it,
# Nearest to the: of, in, and, by, from, on, with, its,
# Nearest to nine: one, seven, eight, three, four, five, six, american,
# Nearest to states: kingdom, united, nations, state, established, federal, canada, union,
# Nearest to th: century, rd, late, nd, early, mid, events, year,
# Nearest to an: a, for, and, with, the, by, to, which,
# Nearest to bill: announced, george, nine, president, leader, s, john, british,
# Nearest to stage: appeared, plays, show, with, performed, movie, success, time,
# Nearest to pope: henry, iii, king, england, iv, john, edward, charles,
# Nearest to channel: satellite, network, via, station, company, owned, program, independent,
# Nearest to shows: for, like, original, a, as, is, also, with,
# Nearest to dr: james, john, peter, richard, david, stephen, sir, michael,
# Nearest to bbc: external, day, news, links, march, april, february, uk,
# Nearest to existence: that, view, some, particular, itself, considered, idea, have,
# Epoch 2/2 Iteration: 23100 Avg. Training loss: 5.3312 0.1023 sec/batch
# Epoch 2/2 Iteration: 23200 Avg. Training loss: 5.3439 0.1046 sec/batch
# Epoch 2/2 Iteration: 23300 Avg. Training loss: 5.4470 0.1040 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
tf.train.get_checkpoint_state('checkpoints')
# Out:
# model_checkpoint_path: "checkpoints/text8.ckpt"
# all_model_checkpoint_paths: "checkpoints/text8.ckpt"

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
